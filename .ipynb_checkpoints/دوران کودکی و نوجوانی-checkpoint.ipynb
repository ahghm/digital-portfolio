# %% [markdown]
# # دوران کودکی و نوجوانی

# %% [markdown]
# ```{figure} ./img/img1.jpg
# ---
# height: 500px
# name: Ali image 1
# ---
#
# ```

# %% [markdown]
# <h3 dir="rtl">در اول تیر ماه ۱۳۱۴ در شهرستان ماهان  استان کرمان چشم به دنیا گشود. او فرزند
# پنجم خانواده بود. یک برادر بزرگتر و سه خواهر بزرگتر و یک خواهر کوچکتر داشت. از همان دوران کوچکی بسیار فعال و کوشا بود. دوره ابتدایی را در ماهان و دوره دبیرستان را در کرمان به اتمام رساند و چون علاقه زیادی به کشاورزی داشت وارد دانشگاه مامازند در رشته کشاورزی شد و در مقطع کاردانی فارغ التحصیل شد.
# </h3>

# %% [markdown]
# ```{figure} ./img/img2.png
# ---
# height: 500px
# name: Ali image 2
# ---
#
# ```

# %% [markdown]
# <h3 dir="rtl"> سپس وارد برنامه توسعه روستایی و اصلاحات کشاورزی شد و چندین سال در استان سیستان و بلوچستان و سراوان مشغول احداث  باغ های متعدد شد .
# </h3>

# %% [markdown]
# ```{figure} ./img/img3.png
# ---
# height: 500px
# name: Ali image 3
# ---
#
# ```
