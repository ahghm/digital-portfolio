# %% [markdown]
# # دوران بازنشستگی

# %% [markdown]
# ```{figure} ./img/img10.jpg
# ---
# height: 500px
# name: Ali image 10
# ---
#
# ```

# %% [markdown]
# <h3 dir="rtl">بعد از حدود ۳۰ سال خدمت بازنشسته شد ولی از انجایکه بسیار فعال بود در زمینه های مختلف و سازمانها و ارگانها ادامه فعالیت داد.</h3>

# %% [markdown]
# ```{figure} ./img/img11.jpg
# ---
# height: 500px
# name: Ali image 11
# ---
#
# ```

# %% [markdown]
# <h3 dir="rtl"> ثمره ازدواج  او ۲ پسر و یک دختر و ۴ نوه می باشد. متاسفانه در سن ۹۰ سالگی بر اثر ابتلا به بیماری انفولانزا پس از ۳ ماه مبارزه در تاریخ ۱۶ اسفند ۱۴۰۴ چشم از جهان گشود و همه عزیزان و وابستگان را داغدار کرد. او همسری وفادار و پدری بسیار مهربان بود. یادش همیشه شاد و گرامی باد.
# </h3>

# %% [markdown]
# ```{figure} ./img/img12.jpg
# ---
# height: 500px
# name: Ali image 12
# ---
#
# ```
